# %% [markdown]
# <a href="https://colab.research.google.com/github/BrayFlo/Mineria-Datos/blob/main/Prueba_Chi_Cuadrado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#07 de Abril del 2026
#Bryan Hernandez Flores

# %%
#Prueba de independencia

# %%
import numpy as np
from scipy import stats

# %%
#Tabla de frecuencias observadas
tabla = np.array([
    [40, 20],
    [30, 30]
])

# %%
#Realiza la prueba de chi cuadrado de independencia stats.chi2_contingency devuelve el esradistico chi-cuadrado, el p-value, los grados de libertad y las frecuencias esperadas

# %%
chi2, p_value, g1, esperados = stats.chi2_contingency(tabla, correction=False)

# %%
#Imprimir resultados
print(f"Estadístico chi-cuadrado= {chi2:.4f}")
print(f"P-value= {p_value:.4f}")
print(f"Grados de libertad = {g1}")
print("Frecuencias esperadas:")
print(esperados)

alpha = 0.05

if p_value < alpha:
    print("Hay evidencia suficiente para determinar que hacer ejercicio depende del genero.")
else:
    print("No hay evidencia suficiente para determinar que hacer ejercicio depende del genero.")
# Out:
# Estadístico chi-cuadrado= 3.4286
# P-value= 0.0641
# Grados de libertad = 1
# Frecuencias esperadas:
# [[35. 25.]
#  [35. 25.]]
# No hay evidencia suficiente para determinar que hacer ejercicio depende del genero.
